# %% [markdown]
# ## Another solution by Максим for reference
# https://maks.live/

# %%
# %%writefile mapper.py

import sys
import re

reload(sys)
sys.setdefaultencoding('utf-8') # required to convert to unicode

def is_name(word):
    letters = tuple(filter(lambda char: char.isalpha(), word))
    if not letters:
        return False
    return letters[0].isupper() and ''.join(letters[1:]).islower()

for line in sys.stdin:
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
    except ValueError as e:
        continue

    text = re.sub("^\W+|\W+$", "", text, flags=re.UNICODE)
    words = re.split("\W*\s+\W*", text, flags=re.UNICODE)

    for word in words:
        print >> sys.stderr, "reporter:counter:Wiki stats,Total words,%d" % 1
        if not bool(word) or word[0].isdigit():
            # filter wrong words
            continue

        if is_name(word):
            print "ok::%s\t%d" % (word.lower(), 1)
        else:
            print "not::%s\t%d" % (word.lower(), 1)
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py

import sys

current_key = None
word_sum = 0

for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    if current_key != key:
        if current_key:
            print "%s\t%d" % (current_key, word_sum)
        word_sum = 0
        current_key = key
    word_sum += count

if current_key:
    print "%s\t%d" % (current_key, word_sum)
# Out:
# Overwriting reducer.py

# %%
# %%writefile reducer_2.py

import sys

current_word = None
word_sum_ok = 0
word_sum_not = 0

PERCENT = 0.5

def print_name_precentage(word, correct, incorrect):
    if not (correct + incorrect):
        print >> sys.stderr, "reporter:counter:Name stats,zero,%d" % 1
    elif (100. * incorrect / (correct + incorrect)) < PERCENT:
        print "%s\t%d" % (word, correct)
        print >> sys.stderr, "reporter:counter:Name stats,name,%d" % 1
    else:
        print >> sys.stderr, "reporter:counter:Name stats,word,%d" % 1

for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        flag, word = key.split('::', 1)
        count = int(count)
    except ValueError as e:
        continue

    if current_word != word:
        print_name_precentage(current_word, word_sum_ok, word_sum_not)
        word_sum_ok = 0
        word_sum_not = 0
        current_word = word        

    if flag == 'ok':
        word_sum_ok += count
    elif flag == 'not':
        word_sum_not += count

if current_word:
    print_name_precentage(current_word, word_sum_ok, word_sum_not)
# Out:
# Overwriting reducer_2.py

# %%
# %%bash
#
# NUM_REDUCERS=8
#
# IN_DIR="/data/wiki/en_articles_part"
# TMP_DIR="namecount_tmp_"$(date +"%s%6N")
# OUT_DIR="namecount_res_"$(date +"%s%6N")
#
# hdfs dfs -rm -r -f -skipTrash ${TMP_DIR} > /dev/null
# hdfs dfs -rm -r -f -skipTrash ${OUT_DIR} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapreduce.job.name="Streaming name count prepare" \
#     -D mapreduce.job.reduces=${NUM_REDUCERS} \
#     -D mapreduce.job.output.key.comparator.class=org.apache.hadoop.mapreduce.lib.partition.KeyFieldBasedComparator \
#     -D mapreduce.map.output.key.field.separator='::' \
#     -D mapreduce.partition.keycomparator.options='-k2' \
#     -files mapper.py,reducer.py \
#     -mapper "python mapper.py" \
#     -combiner "python reducer.py" \
#     -reducer "python reducer.py" \
#     -input ${IN_DIR} \
#     -output ${TMP_DIR} > /dev/null
#
# NUM_REDUCERS=1
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapreduce.job.name="Streaming name count sort result" \
#     -D mapreduce.job.reduces=${NUM_REDUCERS} \
#     -D mapreduce.job.output.key.comparator.class=org.apache.hadoop.mapreduce.lib.partition.KeyFieldBasedComparator \
#     -D mapreduce.map.output.key.field.separator='::' \
#     -D mapreduce.partition.keycomparator.options='-k2' \
#     -files reducer_2.py \
#     -mapper "cat" \
#     -reducer "python reducer_2.py" \
#     -input ${TMP_DIR} \
#     -output ${OUT_DIR} > /dev/null
#
# hdfs dfs -text ${OUT_DIR}/part-00000 | sort -k2rn | head -5 | tail -1
# Out:
# french	5742
# 17/10/26 09:30:14 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/10/26 09:30:14 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/10/26 09:30:15 INFO mapred.FileInputFormat: Total input files to process : 1
# 17/10/26 09:30:15 INFO mapreduce.JobSubmitter: number of splits:2
# 17/10/26 09:30:15 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1509009258921_0007
# 17/10/26 09:30:15 INFO impl.YarnClientImpl: Submitted application application_1509009258921_0007
# 17/10/26 09:30:15 INFO mapreduce.Job: The url to track the job: http://ff5ca7a823c2:8088/proxy/application_1509009258921_0007/
# 17/10/26 09:30:15 INFO mapreduce.Job: Running job: job_1509009258921_0007
# 17/10/26 09:30:23 INFO mapreduce.Job: Job job_1509009258921_0007 running in uber mode : false
# 17/10/26 09:30:23 INFO mapreduce.Job:  map 0% reduce 0%
# 17/10/26 09:30:40 INFO mapreduce.Job:  map 12% reduce 0%
# 17/10/26 09:30:46 INFO mapreduce.Job:  map 18% reduce 0%
# 17/10/26 09:30:52 INFO mapreduce.Job:  map 24% reduce 0%
# 17/10/26 09:30:58 INFO mapreduce.Job:  map 30% reduce 0%
# 17/10/26 09:31:04 INFO mapreduce.Job:  map 35% reduce 0%
# 17/10/26 09:31:10 INFO mapreduce.Job:  map 39% reduce 0%
# 17/10/26 09:31:16 INFO mapreduce.Job:  map 42% reduce 0%
# 17/10/26 09:31:23 INFO mapreduce.Job:  map 44% reduce 0%
# 17/10/26 09:31:29 INFO mapreduce.Job:  map 50% reduce 0%
# 17/10/26 09:31:35 INFO mapreduce.Job:  map 56% reduce 0%
# 17/10/26 09:31:41 INFO mapreduce.Job:  map 62% reduce 0%
# 17/10/26 09:31:47 INFO mapreduce.Job:  map 67% reduce 0%
# 17/10/26 09:31:55 INFO mapreduce.Job:  map 100% reduce 0%
# 17/10/26 09:32:02 INFO mapreduce.Job:  map 100% reduce 13%
# 17/10/26 09:32:07 INFO mapreduce.Job:  map 100% reduce 25%
# 17/10/26 09:32:10 INFO mapreduce.Job:  map 100% reduce 38%
# 17/10/26 09:32:13 INFO mapreduce.Job:  map 100% reduce 50%
# 17/10/26 09:32:14 INFO mapreduce.Job:  map 100% reduce 63%
# 17/10/26 09:32:15 INFO mapreduce.Job:  map 100% reduce 88%
# 17/10/26 09:32:16 INFO mapreduce.Job:  map 100% reduce 100%
# 17/10/26 09:32:16 INFO mapreduce.Job: Job job_1509009258921_0007 completed successfully
# 17/10/26 09:32:16 INFO mapreduce.Job: Counters: 51
# 	File System Counters
# 		FILE: Number of bytes read=24021325
# 		FILE: Number of bytes written=37355128
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=7115747
# 		HDFS: Number of read operations=30
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=16
# 	Job Counters
# 		Killed reduce tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=8
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=179402
# 		Total time spent by all reduces in occupied slots (ms)=80798
# 		Total time spent by all map tasks (ms)=179402
# 		Total time spent by all reduce tasks (ms)=80798
# 		Total vcore-milliseconds taken by all map tasks=179402
# 		Total vcore-milliseconds taken by all reduce tasks=80798
# 		Total megabyte-milliseconds taken by all map tasks=183707648
# 		Total megabyte-milliseconds taken by all reduce tasks=82737152
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=11493421
# 		Map output bytes=149932571
# 		Map output materialized bytes=11983818
# 		Input split bytes=228
# 		Combine input records=11493421
# 		Combine output records=644832
# 		Reduce input groups=414086
# 		Reduce shuffle bytes=11983818
# 		Reduce input records=644832
# 		Reduce output records=414086
# 		Spilled Records=1934496
# 		Shuffled Maps =16
# 		Failed Shuffles=0
# 		Merged Map outputs=16
# 		GC time elapsed (ms)=2524
# 		CPU time spent (ms)=270120
# 		Physical memory (bytes) snapshot=2041757696
# 		Virtual memory (bytes) snapshot=19657117696
# 		Total committed heap usage (bytes)=1600651264
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	Wiki stats
# 		Total words=11937317
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=7115747
# 17/10/26 09:32:16 INFO streaming.StreamJob: Output directory: namecount_tmp_1509010208604258
# 17/10/26 09:32:18 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/10/26 09:32:18 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/10/26 09:32:18 INFO mapred.FileInputFormat: Total input files to process : 8
# 17/10/26 09:32:18 INFO mapreduce.JobSubmitter: number of splits:8
# 17/10/26 09:32:19 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1509009258921_0008
# 17/10/26 09:32:19 INFO impl.YarnClientImpl: Submitted application application_1509009258921_0008
# 17/10/26 09:32:19 INFO mapreduce.Job: The url to track the job: http://ff5ca7a823c2:8088/proxy/application_1509009258921_0008/
# 17/10/26 09:32:19 INFO mapreduce.Job: Running job: job_1509009258921_0008
# 17/10/26 09:32:27 INFO mapreduce.Job: Job job_1509009258921_0008 running in uber mode : false
# 17/10/26 09:32:27 INFO mapreduce.Job:  map 0% reduce 0%
# 17/10/26 09:32:41 INFO mapreduce.Job:  map 75% reduce 0%
# 17/10/26 09:32:47 INFO mapreduce.Job:  map 100% reduce 0%
# 17/10/26 09:32:51 INFO mapreduce.Job:  map 100% reduce 100%
# 17/10/26 09:32:52 INFO mapreduce.Job: Job job_1509009258921_0008 completed successfully
# 17/10/26 09:32:53 INFO mapreduce.Job: Counters: 53
# 	File System Counters
# 		FILE: Number of bytes read=7943947
# 		FILE: Number of bytes written=17145883
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=7116763
# 		HDFS: Number of bytes written=1506796
# 		HDFS: Number of read operations=27
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=1
# 		Launched map tasks=8
# 		Launched reduce tasks=1
# 		Data-local map tasks=8
# 		Total time spent by all maps in occupied slots (ms)=81929
# 		Total time spent by all reduces in occupied slots (ms)=7444
# 		Total time spent by all map tasks (ms)=81929
# 		Total time spent by all reduce tasks (ms)=7444
# 		Total vcore-milliseconds taken by all map tasks=81929
# 		Total vcore-milliseconds taken by all reduce tasks=7444
# 		Total megabyte-milliseconds taken by all map tasks=83895296
# 		Total megabyte-milliseconds taken by all reduce tasks=7622656
# 	Map-Reduce Framework
# 		Map input records=414086
# 		Map output records=414086
# 		Map output bytes=7115758
# 		Map output materialized bytes=7943989
# 		Input split bytes=1016
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=414086
# 		Reduce shuffle bytes=7943989
# 		Reduce input records=414086
# 		Reduce output records=135127
# 		Spilled Records=828172
# 		Shuffled Maps =8
# 		Failed Shuffles=0
# 		Merged Map outputs=8
# 		GC time elapsed (ms)=1550
# 		CPU time spent (ms)=20850
# 		Physical memory (bytes) snapshot=2446651392
# 		Virtual memory (bytes) snapshot=17636167680
# 		Total committed heap usage (bytes)=1718091776
# 	Name stats
# 		name=135127
# 		word=238621
# 		zero=1
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=7115747
# 	File Output Format Counters
# 		Bytes Written=1506796
# 17/10/26 09:32:53 INFO streaming.StreamJob: Output directory: namecount_res_1509010208605140
# sort: write failed: 'standard output': Broken pipe
# sort: write error
