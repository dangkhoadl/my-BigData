# %%
# %%writefile mapper.py

import sys
import re

reload(sys)
sys.setdefaultencoding('utf-8') # required to convert to unicode

for line in sys.stdin:
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
    except ValueError as e:
        continue
    words = re.split("\W*\s+\W*", text, flags=re.UNICODE)
    for word in words:
        print >> sys.stderr, "reporter:counter:Wiki stats,Total words,%d" % 1
        print "%s\t%d" % (word.lower(), 1)
# Out:
# Writing mapper.py

# %%
# %%writefile reducer.py

import sys

current_key = None
word_sum = 0
# Out:
# Writing reducer.py

# %%
# %%writefile -a reducer.py

for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    if current_key != key:
        if current_key:
            print "%s\t%d" % (current_key, word_sum)
        word_sum = 0
        current_key = key
    word_sum += count

if current_key:
    print "%s\t%d" % (current_key, word_sum)
# Out:
# Appending to reducer.py

# %%
! hdfs dfs -ls /data/wiki
# Out:
# Found 1 items
# drwxrwxrwx   - jovyan supergroup          0 2017-10-17 13:15 /data/wiki/en_articles_part

# %%
# %%bash
#
# OUT_DIR="wordcount_result_"$(date +"%s%6N")
# NUM_REDUCERS=8
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapred.jab.name="Streaming wordCount" \
#     -D mapreduce.job.reduces=${NUM_REDUCERS} \
#     -files mapper.py,reducer.py \
#     -mapper "python mapper.py" \
#     -combiner "python reducer.py" \
#     -reducer "python reducer.py" \
#     -input /data/wiki/en_articles_part \
#     -output ${OUT_DIR} > /dev/null
#
# hdfs dfs -cat ${OUT_DIR}/part-00000 | head
# Out:
# 0%however	1
# 0&\mathrm{if	1
# 0(8)320-1234	1
# 0)).(1	2
# 0,03	1
# 0,1,...,n	1
# 0,1,0	1
# 0,1,\dots,n	1
# 0,5	1
# 0,50	1
# rm: `wordcount_result_1516338220652428': No such file or directory
# 18/01/19 05:03:44 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/01/19 05:03:44 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/01/19 05:03:45 INFO mapred.FileInputFormat: Total input files to process : 1
# 18/01/19 05:03:45 INFO mapreduce.JobSubmitter: number of splits:2
# 18/01/19 05:03:45 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1516301725823_0001
# 18/01/19 05:03:46 INFO impl.YarnClientImpl: Submitted application application_1516301725823_0001
# 18/01/19 05:03:46 INFO mapreduce.Job: The url to track the job: http://3702200d895a:8088/proxy/application_1516301725823_0001/
# 18/01/19 05:03:46 INFO mapreduce.Job: Running job: job_1516301725823_0001
# 18/01/19 05:03:53 INFO mapreduce.Job: Job job_1516301725823_0001 running in uber mode : false
# 18/01/19 05:03:53 INFO mapreduce.Job:  map 0% reduce 0%
# 18/01/19 05:04:09 INFO mapreduce.Job:  map 28% reduce 0%
# 18/01/19 05:04:15 INFO mapreduce.Job:  map 42% reduce 0%
# 18/01/19 05:04:21 INFO mapreduce.Job:  map 46% reduce 0%
# 18/01/19 05:04:27 INFO mapreduce.Job:  map 56% reduce 0%
# 18/01/19 05:04:33 INFO mapreduce.Job:  map 67% reduce 0%
# 18/01/19 05:04:37 INFO mapreduce.Job:  map 83% reduce 0%
# 18/01/19 05:04:38 INFO mapreduce.Job:  map 100% reduce 0%
# 18/01/19 05:04:42 INFO mapreduce.Job:  map 100% reduce 25%
# 18/01/19 05:04:43 INFO mapreduce.Job:  map 100% reduce 38%
# 18/01/19 05:04:44 INFO mapreduce.Job:  map 100% reduce 50%
# 18/01/19 05:04:45 INFO mapreduce.Job:  map 100% reduce 63%
# 18/01/19 05:04:46 INFO mapreduce.Job:  map 100% reduce 88%
# 18/01/19 05:04:47 INFO mapreduce.Job:  map 100% reduce 100%
# 18/01/19 05:04:48 INFO mapreduce.Job: Job job_1516301725823_0001 completed successfully
# 18/01/19 05:04:49 INFO mapreduce.Job: Counters: 51
# 	File System Counters
# 		FILE: Number of bytes read=17954826
# 		FILE: Number of bytes written=28258053
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=5370513
# 		HDFS: Number of read operations=30
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=16
# 	Job Counters
# 		Killed reduce tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=8
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=85026
# 		Total time spent by all reduces in occupied slots (ms)=24215
# 		Total time spent by all map tasks (ms)=85026
# 		Total time spent by all reduce tasks (ms)=24215
# 		Total vcore-milliseconds taken by all map tasks=85026
# 		Total vcore-milliseconds taken by all reduce tasks=24215
# 		Total megabyte-milliseconds taken by all map tasks=87066624
# 		Total megabyte-milliseconds taken by all reduce tasks=24796160
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=11937375
# 		Map output bytes=97842436
# 		Map output materialized bytes=8952763
# 		Input split bytes=228
# 		Combine input records=11937375
# 		Combine output records=640011
# 		Reduce input groups=427175
# 		Reduce shuffle bytes=8952763
# 		Reduce input records=640011
# 		Reduce output records=427175
# 		Spilled Records=1920033
# 		Shuffled Maps =16
# 		Failed Shuffles=0
# 		Merged Map outputs=16
# 		GC time elapsed (ms)=1360
# 		CPU time spent (ms)=148800
# 		Physical memory (bytes) snapshot=2322595840
# 		Virtual memory (bytes) snapshot=20214611968
# 		Total committed heap usage (bytes)=1617428480
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	Wiki stats
# 		Total words=11937375
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=5370513
# 18/01/19 05:04:49 INFO streaming.StreamJob: Output directory: wordcount_result_1516338220652428
# cat: Unable to write to output stream.
