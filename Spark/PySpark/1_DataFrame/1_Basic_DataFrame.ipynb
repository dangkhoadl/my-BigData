# %%
import findspark
findspark.init('/home/dangkhoa/spark-2.3.1-bin-hadoop2.7')

# %% [markdown]
# ## Session

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Basic_DataFrame").getOrCreate()

# %% [markdown]
# ## Read dataset

# %%
df = spark.read.json('people.json')

# %%
df.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
df.head(2)
# Out:
# [Row(age=None, name='Michael'), Row(age=30, name='Andy')]

# %%
df.printSchema()
# Out:
# root
#  |-- age: long (nullable = true)
#  |-- name: string (nullable = true)

# %%
df.columns
# Out:
# ['age', 'name']

# %%
df.describe().show()
# Out:
# +-------+------------------+-------+
# |summary|               age|   name|
# +-------+------------------+-------+
# |  count|                 2|      3|
# |   mean|              24.5|   null|
# | stddev|7.7781745930520225|   null|
# |    min|                19|   Andy|
# |    max|                30|Michael|
# +-------+------------------+-------+

# %% [markdown]
# ## Read dataset with structure

# %%
from pyspark.sql.types import (
    StructField,
    StringType,
    IntegerType,
    StructType)

# %%
# Data schema definition
data_schema = [
    StructField("age", IntegerType(), True),
    StructField("name", StringType(), True)]

# Structure definition
data_struct = StructType(fields=data_schema)

# Read df
df = spark.read.json('people.json', schema=data_struct)
df.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %% [markdown]
# ## Select

# %%
df.select('age').show()
# Out:
# +----+
# | age|
# +----+
# |null|
# |  30|
# |  19|
# +----+

# %%
df.select(['age','name']).show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %% [markdown]
# ## Creating new columns

# %%
# Adding a new column with a simple copy
df.withColumn('double_age', df['age'] * 2).show()
# Out:
# +----+-------+----------+
# | age|   name|double_age|
# +----+-------+----------+
# |null|Michael|      null|
# |  30|   Andy|        60|
# |  19| Justin|        38|
# +----+-------+----------+

# %%
# Rename
df.withColumnRenamed('age', 'supernewage').show()
# Out:
# +-----------+-------+
# |supernewage|   name|
# +-----------+-------+
# |       null|Michael|
# |         30|   Andy|
# |         19| Justin|
# +-----------+-------+

# %% [markdown]
# ## Temporary view - SQL

# %%
# Create temp view
df.createOrReplaceTempView('people')
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
results = spark.sql('''
    SELECT * FROM people
    ''')
results.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
results = spark.sql('''
    SELECT *
    FROM people
    WHERE age = 30
    ''')
results.show()
# Out:
# +---+----+
# |age|name|
# +---+----+
# | 30|Andy|
# +---+----+
